# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()
with open("input.txt", 'r') as fp:
    for l in fp.readlines():
        words = l.strip().split()
        G.add_edge(words[1], words[7])

# %%
G.edges
# Out:
# OutEdgeView([('M', 'D'), ('M', 'U'), ('M', 'C'), ('D', 'C'), ('D', 'Y'), ('D', 'N'), ('D', 'O'), ('E', 'Z'), ('E', 'N'), ('E', 'O'), ('E', 'Y'), ('E', 'W'), ('E', 'H'), ('E', 'Q'), ('Z', 'R'), ('Z', 'J'), ('F', 'W'), ('F', 'I'), ('F', 'O'), ('F', 'R'), ('F', 'L'), ('F', 'A'), ('W', 'P'), ('W', 'G'), ('W', 'O'), ('W', 'A'), ('T', 'K'), ('T', 'S'), ('T', 'C'), ('T', 'Q'), ('T', 'P'), ('K', 'Q'), ('K', 'Z'), ('K', 'X'), ('L', 'Z'), ('L', 'G'), ('Q', 'P'), ('Q', 'O'), ('Q', 'A'), ('Q', 'B'), ('Q', 'Y'), ('Q', 'Z'), ('H', 'V'), ('H', 'O'), ('H', 'S'), ('V', 'D'), ('V', 'X'), ('V', 'C'), ('V', 'J'), ('V', 'S'), ('V', 'U'), ('V', 'O'), ('P', 'R'), ('P', 'G'), ('P', 'X'), ('P', 'S'), ('P', 'N'), ('B', 'S'), ('B', 'P'), ('B', 'Y'), ('B', 'A'), ('B', 'D'), ('S', 'U'), ('S', 'Y'), ('R', 'U'), ('R', 'D'), ('R', 'O'), ('R', 'N'), ('A', 'D'), ('A', 'U'), ('A', 'X'), ('A', 'S'), ('G', 'Z'), ('G', 'S'), ('G', 'N'), ('G', 'V'), ('G', 'I'), ('G', 'X'), ('I', 'D'), ('I', 'U'), ('I', 'X'), ('I', 'R'), ('X', 'R'), ('X', 'N'), ('X', 'U'), ('X', 'O'), ('X', 'Y'), ('X', 'C'), ('X', 'S'), ('U', 'Y'), ('U', 'O'), ('J', 'D'), ('J', 'U'), ('J', 'C'), ('J', 'R'), ('J', 'Y'), ('Y', 'N'), ('Y', 'O'), ('N', 'C'), ('O', 'C'), ('O', 'N')])

# %%
nx.draw(G, with_labels=True)
plt.show()

# %%
"".join([c for c in nx.lexicographical_topological_sort(G)])
# Out:
# 'EFHLMTKQBWAPGIVXSZJRDUYONC'
